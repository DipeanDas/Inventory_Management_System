# %%
import json
import time

fd = open('Records.json','r')
js = fd.read()
fd.close()
record = json.loads(js)

print("****Welcome to Dipean's Inventory****")
print("Press X(chocolate),Y(Cake),Z(Chips),A(Any) for Purchase")
Choice=str(input())
print("Columns represent ProductID,Productname,price and Qty available respectively")
print("----------------ITEMLIST-----------------")
if(Choice=="X" or Choice=='x'):
    for key in record.keys():
        if(key=="1001" or key=="1002" or key=="1003" or key=="1004" or key=="1005"):
            print(key, record[key]['Name'], record[key]['Price'], record[key]['Qn'])
elif(Choice=="Y" or Choice=='y'):
    for key in record.keys():
        if(key=="1006" or key=="1007" or key=="1008" or key=="1009" or key=="1010"):
            print(key, record[key]['Name'], record[key]['Price'], record[key]['Qn'])
elif(Choice=="Z" or Choice=='z'):
    for key in record.keys():
        if(key=="1011" or key=="1012" or key=="1013" or key=="1014" or key=="1015"):
            print(key, record[key]['Name'], record[key]['Price'], record[key]['Qn'])
elif(Choice=="A" or Choice=='a'):
    for key in record.keys():        
        print(key, record[key]['Name'], record[key]['Price'], record[key]['Qn'])
else:
    print("Please type any key between x,y and z")
print("-------------------------------------")
print('')

ui_name = str(input("Enter your name    : "))
ui_mail = str(input("Enter Mail ID      : "))
ui_ph   = str(input("Enter Phone No     : "))
ui_pr   = str(input("Enter product ID   : "))
ui_qn   = int(input("Enter Quantity     : "))

print("-------------------------------------")
print('')

if (record[ui_pr]['Qn'] >= ui_qn):

    print("Name      : ", record[ui_pr]["Name"])
    print("Price (Rs): ", record[ui_pr]["Price"])
    print("Quantity  : ", ui_qn)
    print("------------------------------------")
    Billings=(ui_qn * record[ui_pr]["Price"])
    print("Billing   : ",format(Billings,".2f"), "Rs")
    SGSTs=((ui_qn * record[ui_pr]["Price"])*0.025)
    print("SGST      : ",format(SGSTs,".2f"),"Rs")
    CGSTs=((ui_qn * record[ui_pr]["Price"])*0.025)
    print("CGST      : ",format(CGSTs,".2f"),"Rs")    
    if(Billings>=500):
        Discountn=((ui_qn * record[ui_pr]["Price"])*0.1)
        print("Discount  : ",format(Discountn,".2f"),"Rs")
        print("Total Bill:",format((Billings+SGSTs+CGSTs-Discountn),".2f"),"Rs")
    else:
        Discountn=((ui_qn * record[ui_pr]["Price"])*0)
        print("Discount  : ",format(Discountn,".2f"),"Rs")
        print("Total Bill:",format((Billings+SGSTs+CGSTs-Discountn),".2f"),"Rs")
       
    print("------------------------------------")

    record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
    
    sale = ui_name+","+ui_mail+","+ui_ph+","+ui_pr+","+record[ui_pr]["Name"]+","+str(ui_qn)+","+str(record[ui_pr]["Price"])+","+str(format((Billings+SGSTs+CGSTs-Discountn),".2f"))+","+time.ctime()+"\n"

else:
    
    print("Sorry, We're not having enough quanity of product in our Inventory.")
    print("We're only having " + str(record[ui_pr]['Qn']) + " quantity.")
    print("---------------------------------------------")
    
    ch == str(input("Press Y to purchase: "))
    
    if(ch == "Y" or ch == 'y'):

        print("Name      : ", record[ui_pr]["Name"])
        print("Price (Rs): ", record[ui_pr]["Price"])
        print("Quantity  : ", ui_qn)
        print("------------------------------------")
        Billings=(record[ui_pr]['Qn'] * record[ui_pr]["Price"])
        print("Billing   : ", format(Billing,".2f"), "Rs")
        SGST=((record[ui_pr]['Qn'] * record[ui_pr]["Price"])*0.025)
        print("SGST      : ",format(SGST,".2f"),"Rs")
        CGST=((record[ui_pr]['Qn'] * record[ui_pr]["Price"])*0.025)
        print("CGST      : ",format(CGST,".2f"),"Rs")    
        if(Billing>=500):
            Discounts=((record[ui_pr]['Qn'] * record[ui_pr]["Price"])*0.1)
            print("Discount  : ",format(Discounts,".2f"),"Rs")
            print("Total Bill:",format((Billing+SGST+CGST-Discounts),".2f"),"Rs")   
        else:
            Discounts=((record[ui_pr]['Qn'] * record[ui_pr]["Price"])*0)
            print("Discount  : ",format(Discounts,".2f"),"Rs")
            print("Total Bill:",format((Billing+SGST+CGST-Discounts),".2f"),"Rs")   
        print("------------------------------------")
                
        sale = ui_name+","+ui_mail+","+ui_ph+","+ui_pr+","+record[ui_pr]["Name"]+","+str(record[ui_pr]['Qn'])+","+str(record[ui_pr]["Price"])+","+str(format((Billing+SGST+CGST-Discounts),".2f"))+","+time.ctime()+"\n"
        record[ui_pr]['Qn'] = 0
    else:
        print("Thanks!")
        
js = json.dumps(record)

fd = open('Records.json','w')
fd.write(js)
fd.close()

fd = open('Salesjs.txt','a')
fd.write(sale)
fd.close()

print('')
print("---------------------------------------------")
print("  Thanks for your order, Have a nice day! ")
print("---------------------------------------------")
